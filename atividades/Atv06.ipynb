// %% [markdown]
// # Lista exercicios 06

// %% [markdown]
// ## Siga as instruções de cada exercício e utilize a estrutura de desvio de fluxo if else e a classe Scanner para interagir com o usuário e realizar os procedimentos necessários.

// %% [markdown]
// 1 - Crie uma classe em Java solicitando ao usuário para insirir o valor total de uma compra e o tipo de cliente (regular ou especial). Se for cliente especial, conceda um desconto de 10% no valor total. Caso contrário, conceda um desconto de 5%. Em seguida, exiba o valor final após o desconto.

// %%
import java.util.Scanner; 

//public class ex01 {
	//public static void main (String args[]) {
		
        Scanner j = new Scanner(System.in); 
        double valor_Compra, desconto_Especial, desconto_Regular, valor_FinalEspecial, valor_FinalRegular;

		System.out.print("valor total da compra: "); 
		valor_Compra = j.nextInt();

        System.out.print("tipo de cliente (especial ou regular): ");
		String tipo_Cliente = j.next();


        if (tipo_Cliente == "especial" ) {
            desconto_Especial = valor_Compra * 0.1;
            valor_FinalEspecial = valor_Compra - desconto_Especial;
            System.out.println("Valor final da compra: " + valor_FinalEspecial);
            
        } else {
            desconto_Regular = valor_Compra * 0.05;
            valor_FinalRegular = valor_Compra - desconto_Regular;
            System.out.println("Valor final da compra: " + valor_FinalRegular);
        } 

		//s.close();
	//}	
//}
// Out:
// valor total da compra:
//  20
// tipo de cliente (especial ou regular):
//  especial
// Valor final da compra: 19.0
// null

// %% [markdown]
// 2 - Crie uma classe em Java que peça ao usuário para inserir um ano e verifique se é um ano bissexto ou não. Um ano bissexto é aquele que é divisível por 4, exceto os anos que são divisíveis por 100, a menos que sejam divisíveis por 400.

// %%
import java.util.Scanner;

//public class ex2 {
	//public static void main (String args[]) {
		
        Scanner j = new Scanner(System.in); 
        int ano;

		System.out.print("Insira um Ano: "); 
		ano = j.nextInt(); 

        if (ano % 4 == 0 && ano % 100 != 0 ) { 
            
            System.out.println("Eh um Ano Bissexto");
            
        } else if (ano % 100 == 0 && ano % 400 == 0) { 
            System.out.println("Eh um Ano Bissexto.");
        } else {
             System.out.println("Não eh um ano Bissexto.");
        }

		//s.close(); 
	//}	
//}
// Out:
// Insira um Ano:
//  34
// Não eh um ano Bissexto.
// null

// %% [markdown]
// 3 - Crie uma classe em Java que solicite ao usuário para inserir três números e ordene-os em ordem crescente utilizando estruturas de if else.

// %%
import java.util.Scanner;

//public class ex2 {
	//public static void main (String args[]) {
		
        Scanner j = new Scanner(System.in);
        int a, b, c, menor, medio, maior;

		System.out.print("Insira um valor: "); 
		a = j.nextInt(); 

        System.out.print("Insira um segundo valor: "); 
		b = j.nextInt(); 

        System.out.print("Insira um terceiro valor: ");
		c = j.nextInt(); 

        menor = a;
        medio = b;
        maior = c;

        if (b < a && c > a && b < c) {
            menor = b;
            medio = a;
            maior = c;
        } else if (c < a && b < c && a > b) {
            menor = b;
            medio = c;
            maior = a; 
        } else if (c < b && b < a && a > c){
            menor = c;
            medio = b;
            maior = a;
        
        } else if (a < b && a < c && c < b) {
            menor = a;
            medio = c;
            maior = b;
        } else if (c < a && c < b && a < b) {
            menor = c;
            medio = a;
            maior = b;
        } else {
            menor = a;
            medio = b;
            maior = c;
        }

        System.out.println("Ordem crescente: " + menor + " " + medio + " " + maior);


		//s.close(); 
	//}	
//}
// Out:
// Insira um valor:
//  45
// Insira um segundo valor:
//  78
// Insira um terceiro valor:
//  79
// Ordem crescente: 45 78 79
// null

// %% [markdown]
// 4 - Crie uma classe em Java que solicite uma letra do usuário e use if else para determinar se é uma vogal ou consoante.

// %%
import java.util.Scanner; 

//public class ex2 {
	//public static void main (String args[]) {
		
        Scanner s = new Scanner(System.in);
        String letra;

		System.out.print("Insira uma letra: "); 
		letra = s.next(); 

        if (letra == "A") {
            System.out.println("É vogal.");
        } else if ( letra == "E") {
            System.out.println("É vogal.");
            
        } else if ( letra == "I") {
            System.out.println("É vogal.");
            
        } else if ( letra == "O") {
        System.out.println("É vogal.");
        
        } else if ( letra == "U") {
            System.out.println("É vogal.");
            
        } else {
             System.out.println("Não é vogal.");
        }

		//s.close(); 
	//}	
//}
// Out:
// Insira uma letra:
//  E
// Não é vogal.
// null

// %% [markdown]
// 5 - Crie uma classe em Java que peça ao usuário para inserir três valores que representem os lados de um triângulo. Use if else para determinar se é um triângulo equilátero, isósceles ou escaleno.

// %%
import java.util.Scanner; 

//public class ex2 {
	//public static void main (String args[]) {
		
        Scanner j = new Scanner(System.in); 
        int a, b, c;

		System.out.print("Primeiro Lado: "); 
		a = j.nextInt(); 
        
        System.out.print("Segundo Lado: ");
		b = j.nextInt(); 

		System.out.print("Terceiro Lado: "); 
		c = j.nextInt(); 

        if (a == b && a == c && b==c) {
            System.out.println("Eh um Triângulo Equilátero.");
        } else if (a != b && a!= c && b != c) {
            System.out.println("Eh um Triângulo Escaleno.");
        } else {
            System.out.println("Eh um Triângulo Isósceles.");
        }
		//s.close(); 
	//}	
//}
// Out:
// Primeiro Lado:
//  3
// Segundo Lado:
//  4
// Terceiro Lado:
//  6
// Eh um Triângulo Escaleno.
// null
